# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import csv
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    marker=Marker(
        colors=['red', 'blue','green' , 'orange']
    ),
    name='MPFGC 55-57',
    textinfo='none',
    values=[20, 1202, 56, 597]
)

trace2 = Pie(
    domain=dict(
        x=[0.5, 1],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    name='MPFGC 55-57',
    textinfo='none',
    values=[33, 1050, 81, 485]
    
)

trace3 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0, 0.49]
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    name='MPFGC 55-57 55-57',
    textinfo='none',
    values=[2, 114, 0, 6]
)

trace4 = Pie(
    domain=dict(
        x=[0.5, 1],
        y=[0, 0.49]
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    name='MPFGC 55-57',
    textinfo='none',
    values=[6, 112, 7, 16]
)


data = Data([trace1, trace2, trace3, trace4])

layout = Layout(
    annotations=Annotations([Annotation(x=0.21, y=1.02, font=Font(size=12), showarrow=False, text='USA 55-57'),
                                              Annotation(x=0.79, y=1.02, font=Font(size=12), showarrow=False, text='UK 55-57'),
                                              Annotation(x=0.21, y=0.48, font=Font(size=12), showarrow=False, text='JAP 55-57'),
                                              Annotation(x=0.79, y=0.48, font=Font(size=12), showarrow=False, text='AUS 55-57')
                            ]),
    autosize=True,
    hovermode='closest',
    height=474,
    title='The most popular scholarships group by country 55-57',
    width=1000
)
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import csv
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.5],
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    marker=Marker(
        colors=['red', 'blue','green' , 'orange']
    ),
    name='MPFGC 55-57',
    textinfo='none',
    values=[3, 126, 0, 58]
)

trace2 = Pie(
    domain=dict(
        x=[0.5, 1],
    ),
    hoverinfo='label+percent+name',
    labels=['MFA', 'MOST', 'MOPH', 'IPST'],
    name='MPFGC 55-57',
    textinfo='none',
    values=[11, 96, 0, 13]
    
)


data = Data([trace1, trace2])

layout = Layout(
    annotations=Annotations([Annotation(x=0.21, y=1.02, font=Font(size=12), showarrow=False, text='GER 55-57'),
                                              Annotation(x=0.79, y=1.02, font=Font(size=12), showarrow=False, text='FRA 55-57')
                            
                            ]),
    autosize=True,
    hovermode='closest',
    title='The most popular scholarships group by country 55-57',
    height=474,
    width=1000
)
fig = Figure(data=data, layout=layout)
iplot(fig)
