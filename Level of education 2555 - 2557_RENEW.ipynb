# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import csv
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.4],
        y=[0.4, 1]
    ),
    hole=0.4,
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    values=[490, 501, 1689, 5, 7]
)

trace2 = Pie(
    domain=dict(
        x=[0.05, 1],
        y=[0.4, 1]
    ),
    hole=0.4,
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    values=[434, 487, 1502, 18, 7]
    
)

trace3 = Pie(
    domain=dict(
        x=[0.7, 1],
        y=[0.4, 1]
    ),
    hole=0.4,
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    values=[424, 564, 1369, 28, 3]
)





data = Data([trace1, trace2, trace3])

layout = Layout(
    annotations=Annotations([Annotation(x=0.17, y=0.72, font=Font(size=12), showarrow=False, text='EDU 55'),
                                              Annotation(x=0.52, y=0.72, font=Font(size=12), showarrow=False, text='EDU 56'),
                                              Annotation(x=0.89, y=0.72, font=Font(size=12), showarrow=False, text='EDU 57')
                            
                            ]),
    autosize=True,
    height=474,
    hovermode=False,
    title='Level of education 2555 - 2557',
    width=1000
)
fig = Figure(data=data, layout=layout)
iplot(fig)

# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import csv
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    textinfo='none',
    values=[490, 501, 1689, 5, 7]
)

trace2 = Pie(
    domain=dict(
        x=[0.5, 1],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    textinfo='none',
    values=[434, 487, 1502, 18, 7]
    
)

trace3 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0, 0.49]
    ),
    hoverinfo='label+percent+name',
    labels=['Bachelor Degree', 'Masters Dregree', 'Doctoral Degree', 'Postgradurate Diploma', 'Secondary School'],
    name='Level of education stats',
    textinfo='none',
    values=[424, 564, 1369, 28, 3]
)



data = Data([trace1, trace2, trace3])

layout = Layout(
    annotations=Annotations([Annotation(x=0.21, y=1.02, font=Font(size=12), showarrow=False, text='EDU 55'),
                                              Annotation(x=0.79, y=1.02, font=Font(size=12), showarrow=False, text='EDU 56'),
                                              Annotation(x=0.21, y=0.48, font=Font(size=12), showarrow=False, text='EDU 57'),
                            ]),
    autosize=True,
    hovermode='closest',
    height=474,
    title='Level of education stattistics',
    width=1000
)
fig = Figure(data=data, layout=layout)
iplot(fig)
