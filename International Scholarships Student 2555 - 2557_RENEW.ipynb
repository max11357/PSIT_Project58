# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
import csv
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['USA', 'UK', 'JAPAN', 'AUSTRALIA', 'GERMANY', 'FRANCE', 'CHINA', 'NETHERLAND'],
    marker = Marker(colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'gray', 'brown']),
    name='Country stats',
    textinfo='none',
    values=[41.86, 31.58, 4.84, 4.29, 3.85, 2.63, 1.17, 1.54]
)

trace2 = Pie(
    domain=dict(
        x=[0.5, 1],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['USA', 'UK', 'JAPAN', 'AUSTRALIA', 'GERMANY', 'FRANCE', 'CHINA', 'NETHERLAND'],
    name='Country stats',
    textinfo='none',
    values=[42.71, 31.42, 4.49, 4.05, 3.85, 2.67, 1.54, 1.17]
    
)
trace3 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0, 0.49]
    ),
    hoverinfo='label+percent+name',
    labels=['USA', 'UK', 'JAPAN', 'AUSTRALIA', 'GERMANY', 'FRANCE', 'CHINA', 'NETHERLAND'],
    name='Country stats',
    textinfo='none',
    values=[40.68, 33.82, 3.83, 3.93, 3.83, 2.54, 1.12, 1.25]
    
)

data = Data([trace1, trace2, trace3])

layout = Layout(
    annotations=Annotations([Annotation(x=0.23, y=1.02, font=Font(size=12), showarrow=False, text='PCS  55'),
                                              Annotation(x=0.78, y=1.02, font=Font(size=12), showarrow=False, text='PCS  56'),
                                              Annotation(x=0.23, y=0.48, font=Font(size=12), showarrow=False, text='PCS  57')
                             ]),

    autosize=True,
    hovermode='closest',
    height=474,
    title='Populations country statistics 2555 - 2557',
    width=1000
)
fig = Figure(data=data, layout=layout)
iplot(fig)
