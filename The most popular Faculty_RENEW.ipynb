# %%
from plotly import __version__
from plotly.graph_objs import *
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot
import plotly.plotly as py
init_notebook_mode()

trace1 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['ENGINEERING', 'BIOLOGY', 'PHYSICS', 'COMPUTER SCIENCE', 'MATHEMATICS', 'LAW', 'CHEMISTRY'],
    marker=Marker(
        colors=['rgb(146, 123, 21)', 'rgb(177, 180, 34)', 'rgb(206, 206, 40)', 'rgb(175, 51, 21)', 'rgb(35, 36, 21)']
    ),
    textinfo='none',
    name='Faculty 55',
    values=[18.2, 11.32, 8.43, 6.03, 5.73, 5.36, 5.07],
)
trace2 = Pie(
    domain=dict(
        x=[0.5, 1],
        y=[0.51, 1]
    ),
    hoverinfo='label+percent+name',
    labels=['ENGINEERING', 'BIOLOGY', 'PHYSICS', 'COMPUTER SCIENCE', 'MATHEMATICS', 'LAW', 'CHEMISTRY'],
    marker=Marker(
        colors=['rgb(146, 123, 21)', 'rgb(177, 180, 34)', 'rgb(206, 206, 40)', 'rgb(175, 51, 21)', 'rgb(35, 36, 21)']
    ),
    name='Faculty 56',
    textinfo='none',
    values=[17.25, 11.5, 8.79, 6.36, 6.19, 5.26, 5.18],
)
trace3 = Pie(
    domain=dict(
        x=[0, 0.5],
        y=[0, 0.49]
    ),
    hoverinfo='label+percent+name',
    labels=['ENGINEERING', 'BIOLOGY', 'PHYSICS', 'COMPUTER SCIENCE', 'MATHEMATICS', 'LAW', 'CHEMISTRY'],
    marker=Marker(
        colors=['rgb(146, 123, 21)', 'rgb(177, 180, 34)', 'rgb(206, 206, 40)', 'rgb(175, 51, 21)', 'rgb(35, 36, 21)']
    ),
    name='Faculty 57',
    textinfo='none',
    values=[15.97, 10.36, 7.7, 6.7, 5.7, 5.62, 5.28],
)
data = Data([trace1, trace2, trace3])
layout = Layout(
    annotations=Annotations([
        Annotation(
            x=0.23,
            y=1.02,
            font=Font(
                size=12
            ),
            showarrow=False,
            text='Fac 55'
        ),
        Annotation(
            x=0.78,
            y=1.02,
            font=Font(
                size=12
            ),
            showarrow=False,
            text='Fac 56'
        ),
        Annotation(
            x=0.23,
            y=0.48,
            font=Font(
                size=12
            ),
            showarrow=False,
            text='Fac 57'
        )
    ]),
    autosize=True,
    height=514,
    hovermode='closest',
    title='The most popular Faculty',
    width=1121
)
fig = Figure(data=data, layout=layout)
iplot(fig)
